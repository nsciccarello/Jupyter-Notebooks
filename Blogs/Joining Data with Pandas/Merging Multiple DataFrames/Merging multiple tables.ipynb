# %%
import pandas as pd
grants = pd.read_csv('C:/Users/nswat/Documents/DataCamp/Datasets/4JoiningDataWPandasDatasets/Small_Business_Grant_Agreements2.csv')
licenses = pd.read_csv('C:/Users/nswat/Documents/DataCamp/Datasets/4JoiningDataWPandasDatasets/licenses.csv')
wards = pd.read_csv('C:/Users/nswat/Documents/DataCamp/Datasets/4JoiningDataWPandasDatasets/ward.csv')

grants_licenses_ward = grants.merge(licenses, on=['address', 'zip'])\
                        .merge(wards, on='ward', suffixes=('_bus', '_ward'))

grants_licenses_ward.head()
# Out:
#                    address_bus  zip_bus  grant                     company  \
# 0              2105 S STATE ST    60616  743.0        REGGIE'S BAR & GRILL
# 1  1113  -01115 W ARGYLE ST  1    60640  775.0              THAI BINH CORP
# 2    2901 W IRVING PARK RD 1ST    60618  763.0                  QUICK SHOP
# 3            2459 W MADISON ST    60612  763.0  CAMPBELL FOOD & LIQUOR INC
#
#    Unnamed: 0_bus  account  ward  aid                    business  \
# 0               0   307071     3  743        REGGIE'S BAR & GRILL
# 1              20    10235    48  775              THAI BINH CORP
# 2              44    10837    33  763                  QUICK SHOP
# 3             107    11512    27  763  CAMPBELL FOOD & LIQUOR INC
#
#    Unnamed: 0_ward             alderman                address_ward  zip_ward
# 0                2           Pat Dowell     5046 SOUTH STATE STREET     60609
# 1               47       Harry Osterman  5533 NORTH BROADWAY AVENUE     60640
# 2               32         Deborah Mell  3001 WEST IRVING PARK ROAD     60618
# 3               26  Walter Burnett, Jr.      4 NORTH WESTERN AVENUE     60612
