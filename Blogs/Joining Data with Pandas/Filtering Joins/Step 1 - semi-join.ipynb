# %%
import pandas as pd
top_tracks = pd.read_csv('C:/Users/nswat/Documents/DataCamp/Datasets/4JoiningDataWPandasDatasets/songs.csv')
genres = pd.read_csv('C:/Users/nswat/Documents/DataCamp/Datasets/4JoiningDataWPandasDatasets/songgenres.csv')

genres_tracks = genres.merge(top_tracks, on='gid')
genres_tracks.head()
# Out:
#    gid           name_x  tid                   name_y                  artist  \
# 0    1     acoustic pop   97             Turning Page        Sleeping At Last
# 1    1     acoustic pop  165                    Brave          Sara Bareilles
# 2    2     alaska indie  208            Foolish Games                   Jewel
# 3    3  alternative r&b  589  Talk (feat. Disclosure)                  Khalid
# 4    4          art pop   40        Dog Days Are Over  Florence + The Machine
#
#              genre  year  bpm
# 0     acoustic pop  2011  125
# 1     acoustic pop  2013  185
# 2     alaska indie  2013  132
# 3  alternative r&b  2019  136
# 4          art pop  2010  150
