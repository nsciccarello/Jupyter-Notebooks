# %%
import pandas as pd
top_tracks = pd.read_csv('C:/Users/nswat/Documents/DataCamp/Datasets/4JoiningDataWPandasDatasets/songs.csv')
genres = pd.read_csv('C:/Users/nswat/Documents/DataCamp/Datasets/4JoiningDataWPandasDatasets/songgenres2.csv')

genres_tracks = genres.merge(top_tracks, on='gid', how='left', indicator=True)

genres_tracks.head()
# Out:
#    gid           name_x    tid                   name_y  \
# 0    1     acoustic pop   97.0             Turning Page
# 1    1     acoustic pop  165.0                    Brave
# 2    2     alaska indie  208.0            Foolish Games
# 3    3  alternative r&b  589.0  Talk (feat. Disclosure)
# 4    4          art pop   40.0        Dog Days Are Over
#
#                    artist            genre    year    bpm _merge
# 0        Sleeping At Last     acoustic pop  2011.0  125.0   both
# 1          Sara Bareilles     acoustic pop  2013.0  185.0   both
# 2                   Jewel     alaska indie  2013.0  132.0   both
# 3                  Khalid  alternative r&b  2019.0  136.0   both
# 4  Florence + The Machine          art pop  2010.0  150.0   both
