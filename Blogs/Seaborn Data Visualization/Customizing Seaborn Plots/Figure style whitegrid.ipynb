# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

masculinity_data = pd.read_csv('C:/Users/nswat/Documents/DataCamp/Datasets/6SeabornDataVisualization/masculinity2.csv', 
                                low_memory=False)

#Customize plot
sns.set_style('whitegrid')

sns.catplot(x='age', 
            y='masculinity_important', 
            data=masculinity_data, 
            hue='feel_masculine', 
            kind='point')

plt.show()
