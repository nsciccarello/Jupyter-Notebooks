# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

air_df_loc_mean = pd.read_csv('C:/Users/nswat/Documents/DataCamp/Datasets/6SeabornDataVisualization/air_df_loc.csv',
                               low_memory=False)

sns.relplot(x='hour', 
            y='NO_2_mean', 
            data=air_df_loc_mean, 
            kind='line', 
            style='location', 
            hue='location', 
            markers=True, 
            dashes=False)

plt.show()
