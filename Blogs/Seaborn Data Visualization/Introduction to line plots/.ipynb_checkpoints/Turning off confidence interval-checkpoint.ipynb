# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

air_df = pd.read_csv('C:/Users/nswat/Documents/DataCamp/Datasets/6SeabornDataVisualization/air_df_loc.csv',
                     low_memory=False)

sns.relplot(x='hour', 
            y='NO_2', 
            data=air_df, 
            kind='line', 
            ci=None)

plt.show()
