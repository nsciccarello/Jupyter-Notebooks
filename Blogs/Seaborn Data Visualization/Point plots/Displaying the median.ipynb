# %%
import matplotlib.pyplot as plt
import seaborn as sns

tips = sns.load_dataset('tips')

sns.catplot(x='smoker', 
            y='total_bill', 
            data=tips, 
            kind='point')

plt.show()
