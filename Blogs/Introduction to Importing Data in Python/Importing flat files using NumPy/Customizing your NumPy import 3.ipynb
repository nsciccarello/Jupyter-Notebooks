# %%
import numpy as np

filename = 'C:/Users/nswat/Documents/DataCamp/Datasets/7IntroToImportingDataInPython/MNIST_header.txt'
data = np.loadtxt(filename, delimiter=',', skiprows=1, usecols=[0, 2])

data
# Out:
# array([[0., 0.],
#        [1., 0.],
#        [4., 0.],
#        [0., 0.],
#        [0., 0.],
#        [7., 0.],
#        [3., 0.],
#        [5., 0.],
#        [3., 0.],
#        [8., 0.],
#        [9., 0.],
#        [1., 0.],
#        [3., 0.],
#        [3., 0.],
#        [1., 0.],
#        [2., 0.],
#        [0., 0.],
#        [7., 0.],
#        [5., 0.],
#        [8., 0.],
#        [6., 0.],
#        [2., 0.],
#        [0., 0.],
#        [2., 0.],
#        [3., 0.],
#        [6., 0.],
#        [9., 0.],
#        [9., 0.],
#        [7., 0.],
#        [8., 0.],
#        [9., 0.],
#        [4., 0.],
#        [9., 0.],
#        [2., 0.],
#        [1., 0.],
#        [3., 0.],
#        [1., 0.],
#        [1., 0.],
#        [4., 0.],
#        [9., 0.],
#        [1., 0.],
#        [4., 0.],
#        [4., 0.],
#        [2., 0.],
#        [6., 0.],
#        [3., 0.],
#        [7., 0.],
#        [7., 0.],
#        [4., 0.],
#        [7., 0.],
#        [5., 0.],
#        [1., 0.],
# ...
