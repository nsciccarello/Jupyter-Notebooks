# %%
import pandas as pd
import matplotlib.pyplot as plt

mens_rowing = pd.read_csv('C:/Users/nswat/Documents/DataCamp/Datasets/5IntroToDataVisMatplotlib/mens_rowing.csv', 
                          index_col=0)
mens_gymnastics = pd.read_csv('C:/Users/nswat/Documents/DataCamp/Datasets/5IntroToDataVisMatplotlib/mens_gymnastics.csv', 
                              index_col=0)

mens_rowing.head()
# Out:
#          ID                          Name Sex  Age  Height  Weight       Team  \
# 158      62             Giovanni Abagnale   M   21     198      90      Italy
# 11648  6346                    Jrmie Azou   M   27     178      71     France
# 14871  8025  Thomas Gabriel Jrmie Baroukh   M   28     183      70     France
# 15215  8214            Jacob Jepsen Barse   M   27     188      73    Denmark
# 18441  9764          Alexander Belonogoff   M   26     187      90  Australia
#
#        NOC        Games  Year  Season            City   Sport  \
# 158    ITA  2016 Summer  2016  Summer  Rio de Janeiro  Rowing
# 11648  FRA  2016 Summer  2016  Summer  Rio de Janeiro  Rowing
# 14871  FRA  2016 Summer  2016  Summer  Rio de Janeiro  Rowing
# 15215  DEN  2016 Summer  2016  Summer  Rio de Janeiro  Rowing
# 18441  AUS  2016 Summer  2016  Summer  Rio de Janeiro  Rowing
#
#                                         Event   Medal
# 158                Rowing Men's Coxless Pairs  Bronze
# 11648  Rowing Men's Lightweight Double Sculls    Gold
# 14871  Rowing Men's Lightweight Coxless Fours  Bronze
# 15215  Rowing Men's Lightweight Coxless Fours  Silver
# 18441           Rowing Men's Quadruple Sculls  Silver

# %%
mens_gymnastics.head()
# Out:
#          ID                         Name Sex  Age  Height  Weight    Team  \
# 794     455  Denis Mikhaylovich Ablyazin   M   24     161      62  Russia
# 796     455  Denis Mikhaylovich Ablyazin   M   24     161      62  Russia
# 797     455  Denis Mikhaylovich Ablyazin   M   24     161      62  Russia
# 18577  9829   David Sagitovich Belyavsky   M   24     165      55  Russia
# 18579  9829   David Sagitovich Belyavsky   M   24     165      55  Russia
#
#        NOC        Games  Year  Season            City       Sport  \
# 794    RUS  2016 Summer  2016  Summer  Rio de Janeiro  Gymnastics
# 796    RUS  2016 Summer  2016  Summer  Rio de Janeiro  Gymnastics
# 797    RUS  2016 Summer  2016  Summer  Rio de Janeiro  Gymnastics
# 18577  RUS  2016 Summer  2016  Summer  Rio de Janeiro  Gymnastics
# 18579  RUS  2016 Summer  2016  Summer  Rio de Janeiro  Gymnastics
#
#                                   Event   Medal
# 794    Gymnastics Men's Team All-Around  Silver
# 796        Gymnastics Men's Horse Vault  Silver
# 797              Gymnastics Men's Rings  Bronze
# 18577  Gymnastics Men's Team All-Around  Silver
# 18579    Gymnastics Men's Parallel Bars  Bronze
