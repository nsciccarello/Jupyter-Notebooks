# %%
import matplotlib.pyplot as plt
import pandas as pd

seattle_weather = pd.read_csv('C:/Users/nswat/Documents/DataCamp/Datasets/5IntroToDataVisMatplotlib/seattle_weather_new.csv')
austin_weather = pd.read_csv('C:/Users/nswat/Documents/DataCamp/Datasets/5IntroToDataVisMatplotlib/austin_weather_new.csv')

fig, ax = plt.subplots()

ax.plot(seattle_weather['MONTH'], seattle_weather['MLY-TAVG-NORMAL'])
ax.plot(austin_weather['MONTH'], austin_weather['MLY-TAVG-NORMAL'])

plt.show()
