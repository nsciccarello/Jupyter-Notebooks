# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

avocados = pd.read_csv('C:/Users/nswat/Documents/DataCamp/Datasets/3DataManipulationWPandas/avocados.csv')

avocados['avg_price'].hist(bins=20)
plt.show()

# %%
avocados['avg_price'].hist(bins=5)
plt.show()
