# %%
import numpy as np
import pandas as pd
avocados = pd.read_csv('C:/Users/nswat/Documents/DataCamp/Datasets/3DataManipulationWPandas/avocados.csv')

avocados
# Out:
#       Unnamed: 0        date          type  year  avg_price         size  \
# 0              0  12/27/2015  conventional  2015       0.95        small
# 1              1  12/20/2015  conventional  2015       0.98        small
# 2              2  12/13/2015  conventional  2015       0.93        small
# 3              3   12/6/2015  conventional  2015       0.89        small
# 4              4  11/29/2015  conventional  2015       0.99        small
# ...          ...         ...           ...   ...        ...          ...
# 1009        1009    2/4/2018       organic  2018       1.53  extra_large
# 1010        1010   1/28/2018       organic  2018       1.61  extra_large
# 1011        1011   1/21/2018       organic  2018       1.63  extra_large
# 1012        1012   1/14/2018       organic  2018       1.59  extra_large
# 1013        1013    1/7/2018       organic  2018       1.51  extra_large
#
#          nb_sold
# 0     9626901.09
# 1     8710021.76
# 2     9855053.66
# 3     9405464.36
# 4     8094803.56
# ...          ...
# 1009     1703.52
# 1010     1270.61
# 1011     1490.02
# 1012     1580.01
# 1013     1289.07
#
# [1014 rows x 7 columns]
